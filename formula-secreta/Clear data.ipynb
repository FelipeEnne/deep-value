# %%
import pandas as pd
import numpy as np
import glob

pd.set_option('display.max_columns', 500)

# %%
# specifying the path to csv files
path = 'C:\\Users\\felip\\Projetos\\deep-value\\formula-secreta\\data-annual'

# csv files in the path
files = glob.glob(path + "/*.csv")
  
# defining an empty list to store 
# content
data_frame = pd.DataFrame()
content = []
  
# checking all the csv files in the 
# specified path
    # reading content of csv file
    # content.append(filename)
for filename in files:
    df = pd.read_csv(filename)
    ticker = filename[-9:-4]
    df["TICKER"] = [ticker, ticker, ticker, ticker]
    content.append(df)
  
# converting content to data frame
data_frame = pd.concat(content)
data_frame
# Out:
#     Unnamed: 0  incomeBeforeTax    netIncome  sellingGeneralAdministrative  \
# 0   2021-12-31       78938000.0   69193000.0                  9.072000e+07
# 1   2020-12-31      120091000.0  113199000.0                  7.560900e+07
# 2   2019-12-31      103685000.0   88742000.0                  4.976000e+07
# 3   2018-12-31      132857000.0  116650000.0                  3.256900e+07
# 0   2021-12-31      138788000.0  118338000.0                  5.709410e+08
# ..         ...              ...          ...                           ...
# 3   2018-12-31      276673000.0  177726000.0                  1.033620e+08
# 0   2021-12-31      110629000.0  158171000.0                  1.693146e+09
# 1   2020-12-31        4965000.0   98181000.0                  1.418675e+09
# 2   2019-12-31      657928000.0  646140000.0                  1.043855e+09
# 3   2018-12-31      653180000.0  644873000.0                  1.167344e+09
#
#      grossProfit         ebit       endDate  operatingIncome  \
# ...

# %%
len(data_frame)
# Out:
# 1036

# %%
data_frame = data_frame.dropna(subset=["amount_shares"], axis=0)
len(data_frame)
# Out:
# 28

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'incomeBeforeTax', 'minorityInterest', 'netIncome',
#        'sellingGeneralAdministrative', 'grossProfit', 'ebit', 'endDate',
#        'operatingIncome', 'otherOperatingExpenses', 'interestExpense',
#        'incomeTaxExpense', 'totalRevenue', 'totalOperatingExpenses',
#        'costOfRevenue', 'totalOtherIncomeExpenseNet',
#        'netIncomeFromContinuingOps', 'netIncomeApplicableToCommonShares',
#        'intangibleAssets', 'capitalSurplus', 'totalLiab',
#        'totalStockholderEquity', 'minorityInterest.1', 'otherCurrentLiab',
#        'totalAssets', 'endDate.1', 'commonStock', 'otherCurrentAssets',
#        'retainedEarnings', 'otherLiab', 'goodWill', 'treasuryStock',
#        'otherAssets', 'cash', 'totalCurrentLiabilities',
#        'deferredLongTermAssetCharges', 'shortLongTermDebt',
#        'otherStockholderEquity', 'propertyPlantEquipment',
#        'totalCurrentAssets', 'netTangibleAssets', 'netReceivables',
# ...

# %%
data_frame1 = data_frame.loc[df['Unnamed: 0'] == '2022-03-31']
data_frame2 = data_frame.loc[df['Unnamed: 0'] == '2021-12-31']
data_frame3 = data_frame.loc[df['Unnamed: 0'] == '2021-09-30']
data_frame4 = data_frame.loc[df['Unnamed: 0'] == '2021-06-30']
len(data_frame1)
# Out:
# 11

# %%
data_frame1
# Out:
#    Unnamed: 0  incomeBeforeTax    netIncome  sellingGeneralAdministrative  \
# 0  2022-03-31        3763000.0    1246000.0                    23215000.0
# 0  2022-03-31       22049000.0   22484000.0                   135020000.0
# 0  2022-03-31       69933000.0   45609000.0                    37904000.0
# 0  2022-03-31        1551000.0    1028000.0                     7441000.0
# 0  2022-03-31       36817000.0   14060000.0                    24555000.0
# 0  2022-03-31       48836000.0   39166000.0                     7176000.0
# 0  2022-06-30      126131000.0   84613000.0                    56353000.0
# 0  2022-03-31         153000.0     106000.0                     2038000.0
# 0  2022-03-31         153000.0     106000.0                     2038000.0
# 0  2022-06-30       38121000.0   32880000.0                    57503000.0
# 0  2022-03-31     -295439000.0 -292117000.0                    74181000.0
#
#    grossProfit         ebit       endDate  operatingIncome  \
# ...

# %%
data_frame1 = data_frame1.dropna(subset=["amount_shares"], axis=1)
