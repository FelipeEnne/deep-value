# %%
import re
import json
from bs4 import BeautifulSoup
import requests
import pandas as pd
from datetime import datetime, timedelta
import pandas_datareader as wp
import yfinance as yf

pd.options.display.max_columns = None

# %%
# https://sistemaswebb3-listados.b3.com.br/indexPage/day/IBOV?language=pt-br
dataColumns =  pd.read_csv('statusinvest-busca-avancada-l.csv', sep=';',encoding='latin-1')
columns = dataColumns.columns
columns
# Out:
# Index(['TICKER', 'PRECO', 'DY', 'P/L', 'P/VP', 'P/ATIVOS', 'MARGEM BRUTA',
#        'MARGEM EBIT', 'MARG. LIQUIDA', 'P/EBIT', 'EV/EBIT',
#        'DIVIDA LIQUIDA / EBIT', 'DIV. LIQ. / PATRI.', 'PSR', 'P/CAP. GIRO',
#        'P. AT CIR. LIQ.', 'LIQ. CORRENTE', 'ROE', 'ROA', 'ROIC',
#        'PATRIMONIO / ATIVOS', 'PASSIVOS / ATIVOS', 'GIRO ATIVOS',
#        'CAGR RECEITAS 5 ANOS', 'CAGR LUCROS 5 ANOS', ' LIQUIDEZ MEDIA DIARIA',
#        ' VPA', ' LPA', ' PEG Ratio', ' VALOR DE MERCADO'],
#       dtype='object')

# %%
cod = dataColumns['TICKER'].to_numpy()
len(cod)
# Out:
# 293

# %%
cod
# Out:
# array(['AALR3', 'ABCB4', 'ABEV3', 'AERI3', 'AESB3', 'AGRO3', 'AGXY3',
#        'ALLD3', 'ALPA4', 'ALPK3', 'ALSO3', 'ALUP11', 'AMAR3', 'AMBP3',
#        'AMER3', 'ANIM3', 'APER3', 'ARML3', 'ARZZ3', 'ASAI3', 'AURA33',
#        'AURE3', 'AZEV3', 'AZEV4', 'AZUL4', 'B3SA3', 'BBAS3', 'BBDC3',
#        'BBDC4', 'BBSE3', 'BEEF3', 'BIDI11', 'BIDI3', 'BIDI4', 'BKBR3',
#        'BLAU3', 'BMGB4', 'BMOB3', 'BOAS3', 'BPAC11', 'BPAN4', 'BRAP3',
#        'BRAP4', 'BRBI11', 'BRFS3', 'BRIT3', 'BRKM3', 'BRKM5', 'BRML3',
#        'BRPR3', 'BRSR6', 'CAML3', 'CARD3', 'CASH3', 'CBAV3', 'CCRO3',
#        'CEAB3', 'CESP6', 'CGRA4', 'CIEL3', 'CLSA3', 'CLSC4', 'CMIG3',
#        'CMIG4', 'CMIN3', 'COCE5', 'COGN3', 'CPFE3', 'CPLE11', 'CPLE3',
#        'CPLE6', 'CRFB3', 'CSAN3', 'CSED3', 'CSMG3', 'CSNA3', 'CURY3',
#        'CVCB3', 'CXSE3', 'CYRE3', 'DASA3', 'DESK3', 'DEXP3', 'DIRR3',
#        'DMMO3', 'DMVF3', 'DXCO3', 'ECOR3', 'EGIE3', 'ELET3', 'ELET6',
#        'ELMD3', 'EMBR3', 'ENAT3', 'ENBR3', 'ENEV3', 'ENGI11', 'ENJU3',
#        'EQTL3', 'ESPA3', 'ETER3', 'EUCA4', 'EVEN3', 'EZTC3', 'FESA4',
#        'FHER3', 'FIQE3', 'FLRY3', 'FRAS3', 'G2DI33', 'GETT11', 'GFSA3',
#        'GGBR3', 'GGBR4', 'GGPS3', 'GMAT3', 'GNDI3', 'GOAU3', 'GOAU4',
#        'GOLL4', 'GRND3', 'GUAR3', 'HAPV3', 'HBOR3', 'HBRE3', 'HBSA3',
#        'HGTX3', 'HYPE3', 'IFCM3', 'IGTA3', 'IGTI11', 'IGTI3', 'INEP3',
#        'INEP4', 'INTB3', 'IRBR3', 'ITSA3', 'ITSA4', 'ITUB3', 'ITUB4',
#        'JALL3', 'JBSS3', 'JHSF3', 'JSLG3', 'KEPL3', 'KLBN11', 'KLBN3',
#        'KLBN4', 'KRSA3', 'LAME3', 'LAME4', 'LAND3', 'LAVV3', 'LCAM3',
#        'LEVE3', 'LIGT3', 'LJQQ3', 'LLIS3', 'LOGG3', 'LOGN3', 'LPSB3',
#        'LREN3', 'LUPA3', 'LVTC3', 'LWSA3', 'MATD3', 'MBLY3', 'MDIA3',
#        'MDNE3', 'MEAL3', 'MEGA3', 'MELK3', 'MGLU3', 'MILS3', 'MLAS3',
#        'MOAR3', 'MODL11', 'MOSI3', 'MOVI3', 'MRFG3', 'MRVE3', 'MTRE3',
#        'MULT3', 'MYPK3', 'NEOE3', 'NGRD3', 'NINJ3', 'NTCO3', 'ODPV3',
#        'OFSA3', 'OIBR3', 'OIBR4', 'OMGE3', 'ONCO3', 'OPCT3', 'ORVR3',
#        'PARD3', 'PCAR3', 'PDGR3', 'PETR3', 'PETR4', 'PETZ3', 'PFRM3',
#        'PGMN3', 'PLPL3', 'PMAM3', 'PNVL3', 'POMO4', 'PORT3', 'POSI3',
#        'POWE3', 'PRIO3', 'PRNR3', 'PSSA3', 'PTBL3', 'QUAL3', 'RADL3',
#        'RAIL3', 'RAIZ4', 'RANI3', 'RAPT4', 'RCSL3', 'RCSL4', 'RDOR3',
#        'RECV3', 'RENT3', 'RNEW3', 'RNEW4', 'ROMI3', 'RRRP3', 'RSID3',
#        'SANB11', 'SANB3', 'SANB4', 'SAPR11', 'SAPR3', 'SAPR4', 'SBFG3',
#        'SBSP3', 'SEER3', 'SEQL3', 'SHOW3', 'SHUL4', 'SIMH3', 'SLCE3',
#        'SMFT3', 'SMTO3', 'SOJA3', 'SOMA3', 'SQIA3', 'STBP3', 'SULA11',
#        'SUZB3', 'SYNE3', 'TAEE11', 'TAEE3', 'TAEE4', 'TASA3', 'TASA4',
#        'TCSA3', 'TECN3', 'TEND3', 'TFCO4', 'TGMA3', 'TIMS3', 'TOTS3',
#        'TPIS3', 'TRAD3', 'TRIS3', 'TRPL4', 'TTEN3', 'TUPY3', 'UCAS3',
#        'UGPA3', 'UNIP3', 'UNIP6', 'USIM3', 'USIM5', 'VALE3', 'VAMO3',
#        'VBBR3', 'VIIA3', 'VITT3', 'VIVA3', 'VIVR3', 'VIVT3', 'VLID3',
#        'VULC3', 'VVEO3', 'WEGE3', 'WEST3', 'WIZS3', 'YDUQ3'], dtype=object)

# %%
#If error
#cod = cod[11:]
#cod
# Out:
# array(['ALUP11', 'AMAR3', 'AMBP3', 'AMER3', 'ANIM3', 'APER3', 'ARML3',
#        'ARZZ3', 'ASAI3', 'AURA33', 'AURE3', 'AZEV3', 'AZEV4', 'AZUL4',
#        'B3SA3', 'BBAS3', 'BBDC3', 'BBDC4', 'BBSE3', 'BEEF3', 'BIDI11',
#        'BIDI3', 'BIDI4', 'BKBR3', 'BLAU3', 'BMGB4', 'BMOB3', 'BOAS3',
#        'BPAC11', 'BPAN4', 'BRAP3', 'BRAP4', 'BRBI11', 'BRFS3', 'BRIT3',
#        'BRKM3', 'BRKM5', 'BRML3', 'BRPR3', 'BRSR6', 'CAML3', 'CARD3',
#        'CASH3', 'CBAV3', 'CCRO3', 'CEAB3', 'CESP6', 'CGRA4', 'CIEL3',
#        'CLSA3', 'CLSC4', 'CMIG3', 'CMIG4', 'CMIN3', 'COCE5', 'COGN3',
#        'CPFE3', 'CPLE11', 'CPLE3', 'CPLE6', 'CRFB3', 'CSAN3', 'CSED3',
#        'CSMG3', 'CSNA3', 'CURY3', 'CVCB3', 'CXSE3', 'CYRE3', 'DASA3',
#        'DESK3', 'DEXP3', 'DIRR3', 'DMMO3', 'DMVF3', 'DXCO3', 'ECOR3',
#        'EGIE3', 'ELET3', 'ELET6', 'ELMD3', 'EMBR3', 'ENAT3', 'ENBR3',
#        'ENEV3', 'ENGI11', 'ENJU3', 'EQTL3', 'ESPA3', 'ETER3', 'EUCA4',
#        'EVEN3', 'EZTC3', 'FESA4', 'FHER3', 'FIQE3', 'FLRY3', 'FRAS3',
#        'G2DI33', 'GETT11', 'GFSA3', 'GGBR3', 'GGBR4', 'GGPS3', 'GMAT3',
#        'GNDI3', 'GOAU3', 'GOAU4', 'GOLL4', 'GRND3', 'GUAR3', 'HAPV3',
#        'HBOR3', 'HBRE3', 'HBSA3', 'HGTX3', 'HYPE3', 'IFCM3', 'IGTA3',
#        'IGTI11', 'IGTI3', 'INEP3', 'INEP4', 'INTB3', 'IRBR3', 'ITSA3',
#        'ITSA4', 'ITUB3', 'ITUB4', 'JALL3', 'JBSS3', 'JHSF3', 'JSLG3',
#        'KEPL3', 'KLBN11', 'KLBN3', 'KLBN4', 'KRSA3', 'LAME3', 'LAME4',
#        'LAND3', 'LAVV3', 'LCAM3', 'LEVE3', 'LIGT3', 'LJQQ3', 'LLIS3',
#        'LOGG3', 'LOGN3', 'LPSB3', 'LREN3', 'LUPA3', 'LVTC3', 'LWSA3',
#        'MATD3', 'MBLY3', 'MDIA3', 'MDNE3', 'MEAL3', 'MEGA3', 'MELK3',
#        'MGLU3', 'MILS3', 'MLAS3', 'MOAR3', 'MODL11', 'MOSI3', 'MOVI3',
#        'MRFG3', 'MRVE3', 'MTRE3', 'MULT3', 'MYPK3', 'NEOE3', 'NGRD3',
#        'NINJ3', 'NTCO3', 'ODPV3', 'OFSA3', 'OIBR3', 'OIBR4', 'OMGE3',
#        'ONCO3', 'OPCT3', 'ORVR3', 'PARD3', 'PCAR3', 'PDGR3', 'PETR3',
#        'PETR4', 'PETZ3', 'PFRM3', 'PGMN3', 'PLPL3', 'PMAM3', 'PNVL3',
#        'POMO4', 'PORT3', 'POSI3', 'POWE3', 'PRIO3', 'PRNR3', 'PSSA3',
#        'PTBL3', 'QUAL3', 'RADL3', 'RAIL3', 'RAIZ4', 'RANI3', 'RAPT4',
#        'RCSL3', 'RCSL4', 'RDOR3', 'RECV3', 'RENT3', 'RNEW3', 'RNEW4',
#        'ROMI3', 'RRRP3', 'RSID3', 'SANB11', 'SANB3', 'SANB4', 'SAPR11',
#        'SAPR3', 'SAPR4', 'SBFG3', 'SBSP3', 'SEER3', 'SEQL3', 'SHOW3',
#        'SHUL4', 'SIMH3', 'SLCE3', 'SMFT3', 'SMTO3', 'SOJA3', 'SOMA3',
#        'SQIA3', 'STBP3', 'SULA11', 'SUZB3', 'SYNE3', 'TAEE11', 'TAEE3',
#        'TAEE4', 'TASA3', 'TASA4', 'TCSA3', 'TECN3', 'TEND3', 'TFCO4',
#        'TGMA3', 'TIMS3', 'TOTS3', 'TPIS3', 'TRAD3', 'TRIS3', 'TRPL4',
#        'TTEN3', 'TUPY3', 'UCAS3', 'UGPA3', 'UNIP3', 'UNIP6', 'USIM3',
#        'USIM5', 'VALE3', 'VAMO3', 'VBBR3', 'VIIA3', 'VITT3', 'VIVA3',
#        'VIVR3', 'VIVT3', 'VLID3', 'VULC3', 'VVEO3', 'WEGE3', 'WEST3',
#        'WIZS3', 'YDUQ3'], dtype=object)

# %%
urlFundamental = 'https://finance.yahoo.com/quote/{0}.SA/financials?p={1}.SA'
count = 0

# %%
for stock in cod:
    # 2 Return HTML
    url = urlFundamental.format(stock,stock)

    headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.61 Safari/537.36'}
    resp = requests.get(url,headers= headers)
    print(url, resp, count)
    count = count + 1
    
    # 3 Filter page
    brute = BeautifulSoup(resp.text, "html.parser")
    pattern = re.compile(r'\s--\sData\s--\s')
        
        
    brute_datas = brute.find('script', text = pattern).contents[0]
    init = brute_datas.find("context")-2
    dados_json =json.loads(brute_datas[init:-12])

    # 4 Return Income Statement
    income_statement = dados_json['context']['dispatcher']['stores']['QuoteSummaryStore']['incomeStatementHistoryQuarterly']['incomeStatementHistory']

    financial_quarterly = []
    for s in income_statement:
        balance = {}
        for key, val in s.items():
            try:
                balance[key] = val["raw"]
            except TypeError:
                continue
            except KeyError:
                continue
        financial_quarterly.append(balance)


    annual_index = []
    annual_0 = pd.DataFrame.from_dict(financial_quarterly[0], orient="index").transpose()
    annual_0 = annual_0.rename(index={0: pd.to_datetime(annual_0["endDate"], unit='s')[0]}) 
    annual_index.append(pd.to_datetime(annual_0["endDate"], unit='s')[0])
    annual_1 = pd.DataFrame.from_dict(financial_quarterly[1], orient="index").transpose()
    annual_1 = annual_1.rename(index={0:  pd.to_datetime(annual_1["endDate"], unit='s')[0]}) 
    annual_index.append(pd.to_datetime(annual_1["endDate"], unit='s')[0])
    annual_2 = pd.DataFrame.from_dict(financial_quarterly[2], orient="index").transpose()
    annual_2 = annual_2.rename(index={0: pd.to_datetime(annual_2["endDate"], unit='s')[0]}) 
    annual_index.append(pd.to_datetime(annual_2["endDate"], unit='s')[0])
    annual_3 = pd.DataFrame.from_dict(financial_quarterly[3], orient="index").transpose()
    annual_3 = annual_3.rename(index={0:  pd.to_datetime(annual_3["endDate"], unit='s')[0]}) 
    annual_index.append(pd.to_datetime(annual_3["endDate"], unit='s')[0])

    income_statement = pd.concat([annual_0, annual_1, annual_2, annual_3])

    # 5 Balance sheet
    balance_sheet = dados_json['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistoryQuarterly']['balanceSheetStatements']

    balace_sheet_quarterly = []
    for s in balance_sheet:
        balance = {}
        for key, val in s.items():
            try:
                balance[key] = val["raw"]
            except TypeError:
                continue
            except KeyError:
                continue
        balace_sheet_quarterly.append(balance)

    bs_annual_0 = pd.DataFrame.from_dict(balace_sheet_quarterly[0], orient="index").transpose()
    bs_annual_0 = bs_annual_0.rename(index={0: pd.to_datetime(bs_annual_0["endDate"], unit='s')[0]}) 
    bs_annual_1 = pd.DataFrame.from_dict(balace_sheet_quarterly[1], orient="index").transpose()
    bs_annual_1 = bs_annual_1.rename(index={0: pd.to_datetime(bs_annual_1["endDate"], unit='s')[0]}) 
    bs_annual_2 = pd.DataFrame.from_dict(balace_sheet_quarterly[2], orient="index").transpose()
    bs_annual_2 = bs_annual_2.rename(index={0: pd.to_datetime(bs_annual_2["endDate"], unit='s')[0]}) 
    bs_annual_3 = pd.DataFrame.from_dict(balace_sheet_quarterly[3], orient="index").transpose()
    bs_annual_3 = bs_annual_3.rename(index={0: pd.to_datetime(bs_annual_3["endDate"], unit='s')[0]}) 

    bs_annual = pd.concat([bs_annual_0, bs_annual_1, bs_annual_2, bs_annual_3])

    ic_transpose = income_statement.transpose()
    bs_transpose = bs_annual.transpose()
    final = pd.concat([ic_transpose, bs_transpose])
    final = final.transpose()
        
    fileName = "data/{}.csv"
    fileName = fileName.format(stock)
    print(fileName)
        
    try:
        stockName = "{}.SA"
        stockName = stockName.format(stock)
        stock_0 = wp.DataReader(stockName, data_source="yahoo", start=annual_index[0] - timedelta(days=15),end=annual_index[0] - timedelta(days=10))
        stock_0 = stock_0.drop(stock_0.columns[[0,1,2,3,4]], axis = 1)
        stock_1 = wp.DataReader(stockName, data_source="yahoo", start=annual_index[1] - timedelta(days=15),end=annual_index[1] - timedelta(days=10))
        stock_1 = stock_1.drop(stock_1.columns[[0,1,2,3,4]], axis = 1)
        stock_2 = wp.DataReader(stockName, data_source="yahoo", start=annual_index[2] - timedelta(days=15),end=annual_index[2] - timedelta(days=10))
        stock_2 = stock_2.drop(stock_2.columns[[0,1,2,3,4]], axis = 1)
        stock_3 = wp.DataReader(stockName, data_source="yahoo", start=annual_index[3] - timedelta(days=15),end=annual_index[3] - timedelta(days=10))
        stock_3 = stock_3.drop(stock_3.columns[[0,1,2,3,4]], axis = 1)
    except TypeError:
        continue
    except KeyError:
        continue
        
    try:
        amount_shares_0 = dados_json['context']['dispatcher']['stores']['QuoteTimeSeriesStore']["timeSeries"]['annualBasicAverageShares'][0]["reportedValue"]["raw"]
        final["amount_shares"] = [amount_shares_0, amount_shares_0, amount_shares_0, amount_shares_0]
    except TypeError:
        continue
    except KeyError:
        continue
    price_stock_0 = stock_0.iloc[0,0]
    price_stock_1 = stock_1.iloc[0,0]
    price_stock_2 = stock_2.iloc[0,0]
    price_stock_3 = stock_3.iloc[0,0]
        
    final["price_stock"] = [price_stock_0,price_stock_1,price_stock_2,price_stock_3]
    final["LPA"] = final["netIncomeApplicableToCommonShares"]/final["amount_shares"]
    final["preco_lucro"] = final["price_stock"]/final["LPA"]
    final["P/VP"] = final["price_stock"]*final["amount_shares"]
    final["PL"] = final["totalCurrentLiabilities"]*final["amount_shares"]
    final["P/ATIVO"] = final["price_stock"]/(final["totalAssets"]/final["amount_shares"])
    final["VPA"] = final["totalStockholderEquity"]/final["amount_shares"]
    final["VM"] = final["amount_shares"]*final["price_stock"]
    final["EV"] = final["VM"]+final["shortLongTermDebt"]-final["cash"]
    final["EV"] = final["VM"]+final["shortLongTermDebt"]-final["cash"]
    final["EV/EBIT"] = final["EV"]/final["ebit"]
    final["NOPAT"] = final["ebit"]-final["incomeTaxExpense"]
    try:
        final["ROIC-I"] = final["NOPAT"]/final["longTermInvestments"]
    except TypeError:
        final.to_csv(fileName)
    except KeyError:
        final.to_csv(fileName)
    final["formula-gharant"] = (final["VPA"]*final["LPA"]*22.5)**0.5
    final["margem-seguranca"] = (final["formula-gharant"]/final["price_stock"]-1)*100

        
    final.to_csv(fileName)
# Out:
# https://finance.yahoo.com/quote/AALR3.SA/financials?p=AALR3.SA <Response [200]> 1
# data/AALR3.csv
# dict_keys(['regularMarketPrice', 'preMarketPrice', 'logo_url'])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [50], in <cell line: 1>()
#     102 Ticker = yf.Ticker(stock)
#     103 print(Ticker.info.keys())
# --> 104 amount_shares_0 = Ticker.info['sharesOutstanding']
#     105 final["amount_shares"] = [amount_shares_0, amount_shares_0, amount_shares_0, amount_shares_0]
#     107 price_stock_0 = stock_0.iloc[0,0]
#
# KeyError: 'sharesOutstanding'

# %%
Amazon = yf.Ticker("AMZN") 
print(Amazon.info.keys())
# Out:
# dict_keys(['zip', 'sector', 'fullTimeEmployees', 'longBusinessSummary', 'city', 'phone', 'state', 'country', 'companyOfficers', 'website', 'maxAge', 'address1', 'industry', 'ebitdaMargins', 'profitMargins', 'grossMargins', 'operatingCashflow', 'revenueGrowth', 'operatingMargins', 'ebitda', 'targetLowPrice', 'recommendationKey', 'grossProfits', 'freeCashflow', 'targetMedianPrice', 'currentPrice', 'earningsGrowth', 'currentRatio', 'returnOnAssets', 'numberOfAnalystOpinions', 'targetMeanPrice', 'debtToEquity', 'returnOnEquity', 'targetHighPrice', 'totalCash', 'totalDebt', 'totalRevenue', 'totalCashPerShare', 'financialCurrency', 'revenuePerShare', 'quickRatio', 'recommendationMean', 'exchange', 'shortName', 'longName', 'exchangeTimezoneName', 'exchangeTimezoneShortName', 'isEsgPopulated', 'gmtOffSetMilliseconds', 'quoteType', 'symbol', 'messageBoardId', 'market', 'annualHoldingsTurnover', 'enterpriseToRevenue', 'beta3Year', 'enterpriseToEbitda', '52WeekChange', 'morningStarRiskRating', 'forwardEps', 'revenueQuarterlyGrowth', 'sharesOutstanding', 'fundInceptionDate', 'annualReportExpenseRatio', 'totalAssets', 'bookValue', 'sharesShort', 'sharesPercentSharesOut', 'fundFamily', 'lastFiscalYearEnd', 'heldPercentInstitutions', 'netIncomeToCommon', 'trailingEps', 'lastDividendValue', 'SandP52WeekChange', 'priceToBook', 'heldPercentInsiders', 'nextFiscalYearEnd', 'yield', 'mostRecentQuarter', 'shortRatio', 'sharesShortPreviousMonthDate', 'floatShares', 'beta', 'enterpriseValue', 'priceHint', 'threeYearAverageReturn', 'lastSplitDate', 'lastSplitFactor', 'legalType', 'lastDividendDate', 'morningStarOverallRating', 'earningsQuarterlyGrowth', 'priceToSalesTrailing12Months', 'dateShortInterest', 'pegRatio', 'ytdReturn', 'forwardPE', 'lastCapGain', 'shortPercentOfFloat', 'sharesShortPriorMonth', 'impliedSharesOutstanding', 'category', 'fiveYearAverageReturn', 'previousClose', 'regularMarketOpen', 'twoHundredDayAverage', 'trailingAnnualDividendYield', 'payoutRatio', 'volume24Hr', 'regularMarketDayHigh', 'navPrice', 'averageDailyVolume10Day', 'regularMarketPreviousClose', 'fiftyDayAverage', 'trailingAnnualDividendRate', 'open', 'toCurrency', 'averageVolume10days', 'expireDate', 'algorithm', 'dividendRate', 'exDividendDate', 'circulatingSupply', 'startDate', 'regularMarketDayLow', 'currency', 'trailingPE', 'regularMarketVolume', 'lastMarket', 'maxSupply', 'openInterest', 'marketCap', 'volumeAllCurrencies', 'strikePrice', 'averageVolume', 'dayLow', 'ask', 'askSize', 'volume', 'fiftyTwoWeekHigh', 'fromCurrency', 'fiveYearAvgDividendYield', 'fiftyTwoWeekLow', 'bid', 'tradeable', 'dividendYield', 'bidSize', 'dayHigh', 'coinMarketCapLink', 'regularMarketPrice', 'preMarketPrice', 'logo_url', 'trailingPegRatio'])

# %%
for stock in cod:
    try:
         # 2 Return HTML
        url = urlFundamental.format(stock,stock)

        headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.61 Safari/537.36'}
        resp = requests.get(url,headers= headers)
        print(url, resp)
        # 3 Filter page
        try:
            brute = BeautifulSoup(resp.text, "html.parser")
            pattern = re.compile(r'\s--\sData\s--\s')
            try:
                brute_datas = brute.find('script', text = pattern).contents[0]
            except TypeError:
                continue
            except KeyError:
                continue

            init = brute_datas.find("context")-2
            dados_json =json.loads(brute_datas[init:-12])

            # 4 Return Income Statement
            income_statement = dados_json['context']['dispatcher']['stores']['QuoteSummaryStore']['incomeStatementHistory']['incomeStatementHistory']
            financial_quarterly = []
            for s in income_statement:
                balance = {}
                for key, val in s.items():
                    try:
                        balance[key] = val["raw"]
                    except TypeError:
                        continue
                    except KeyError:
                        continue
                financial_quarterly.append(balance)


            annual_index = []
            annual_0 = pd.DataFrame.from_dict(financial_quarterly[0], orient="index").transpose()
            annual_0 = annual_0.rename(index={0: pd.to_datetime(annual_0["endDate"], unit='s')[0]}) 
            annual_index.append(pd.to_datetime(annual_0["endDate"], unit='s')[0])
            annual_1 = pd.DataFrame.from_dict(financial_quarterly[1], orient="index").transpose()
            annual_1 = annual_1.rename(index={0:  pd.to_datetime(annual_1["endDate"], unit='s')[0]}) 
            annual_index.append(pd.to_datetime(annual_1["endDate"], unit='s')[0])
            annual_2 = pd.DataFrame.from_dict(financial_quarterly[2], orient="index").transpose()
            annual_2 = annual_2.rename(index={0: pd.to_datetime(annual_2["endDate"], unit='s')[0]}) 
            annual_index.append(pd.to_datetime(annual_2["endDate"], unit='s')[0])
            annual_3 = pd.DataFrame.from_dict(financial_quarterly[3], orient="index").transpose()
            annual_3 = annual_3.rename(index={0:  pd.to_datetime(annual_3["endDate"], unit='s')[0]}) 
            annual_index.append(pd.to_datetime(annual_3["endDate"], unit='s')[0])

            income_statement = pd.concat([annual_0, annual_1, annual_2, annual_3])

            # 5 Balance sheet
            balance_sheet = dados_json['context']['dispatcher']['stores']['QuoteSummaryStore']['balanceSheetHistory']['balanceSheetStatements']
            balace_sheet_quarterly = []
            for s in balance_sheet:
                balance = {}
                for key, val in s.items():
                    try:
                        balance[key] = val["raw"]
                    except TypeError:
                        continue
                    except KeyError:
                        continue
                balace_sheet_quarterly.append(balance)

            bs_annual_0 = pd.DataFrame.from_dict(balace_sheet_quarterly[0], orient="index").transpose()
            bs_annual_0 = bs_annual_0.rename(index={0: pd.to_datetime(bs_annual_0["endDate"], unit='s')[0]}) 
            bs_annual_1 = pd.DataFrame.from_dict(balace_sheet_quarterly[1], orient="index").transpose()
            bs_annual_1 = bs_annual_1.rename(index={0: pd.to_datetime(bs_annual_1["endDate"], unit='s')[0]}) 
            bs_annual_2 = pd.DataFrame.from_dict(balace_sheet_quarterly[2], orient="index").transpose()
            bs_annual_2 = bs_annual_2.rename(index={0: pd.to_datetime(bs_annual_2["endDate"], unit='s')[0]}) 
            bs_annual_3 = pd.DataFrame.from_dict(balace_sheet_quarterly[3], orient="index").transpose()
            bs_annual_3 = bs_annual_3.rename(index={0: pd.to_datetime(bs_annual_3["endDate"], unit='s')[0]}) 

            bs_annual = pd.concat([bs_annual_0, bs_annual_1, bs_annual_2, bs_annual_3])

            ic_transpose = income_statement.transpose()
            bs_transpose = bs_annual.transpose()
            final = pd.concat([ic_transpose, bs_transpose])
            final = final.transpose()

            fileName = "data-annual/{}.csv"
            fileName = fileName.format(stock)
            print(fileName)
        except TypeError:
            continue
        except KeyError:
            continue
        except IndexError:
            continue
        except IndexError:
            continue
        
        try:
            stockName = "{}.SA"
            stockName = stockName.format(stock)
            stock_0 = wp.DataReader(stockName, data_source="yahoo", start=annual_index[0] - timedelta(days=15),end=annual_index[0] - timedelta(days=10))
            stock_0 = stock_0.drop(stock_0.columns[[0,1,2,3,4]], axis = 1)
            stock_1 = wp.DataReader(stockName, data_source="yahoo", start=annual_index[1] - timedelta(days=15),end=annual_index[1] - timedelta(days=10))
            stock_1 = stock_1.drop(stock_1.columns[[0,1,2,3,4]], axis = 1)
            stock_2 = wp.DataReader(stockName, data_source="yahoo", start=annual_index[2] - timedelta(days=15),end=annual_index[2] - timedelta(days=10))
            stock_2 = stock_2.drop(stock_2.columns[[0,1,2,3,4]], axis = 1)
            stock_3 = wp.DataReader(stockName, data_source="yahoo", start=annual_index[3] - timedelta(days=15),end=annual_index[3] - timedelta(days=10))
            stock_3 = stock_3.drop(stock_3.columns[[0,1,2,3,4]], axis = 1)
        except TypeError:
            continue
        except KeyError:
            continue
        except NoneType:
            continue
            
        
        try:
            amount_shares_0 = dados_json['context']['dispatcher']['stores']['QuoteTimeSeriesStore']["timeSeries"]['annualBasicAverageShares'][0]["reportedValue"]["raw"]
            final["amount_shares"] = [amount_shares_0, amount_shares_0, amount_shares_0, amount_shares_0]

            price_stock_0 = stock_0.iloc[0,0]
            price_stock_1 = stock_1.iloc[0,0]
            price_stock_2 = stock_2.iloc[0,0]
            price_stock_3 = stock_3.iloc[0,0]
            final["price_stock"] = [price_stock_0,price_stock_1,price_stock_2,price_stock_3]
        except TypeError:
            continue
        except KeyError:
            continue
        except IndexError:
            continue
         
        try:
            final["LPA"] = final["netIncomeApplicableToCommonShares"]/final["amount_shares"]
            final["preco_lucro"] = final["price_stock"]/final["LPA"]
            final["P/VP"] = final["price_stock"]*final["amount_shares"]
            final["PL"] = final["totalCurrentLiabilities"]*final["amount_shares"]
            final["P/ATIVO"] = final["price_stock"]/(final["totalAssets"]/final["amount_shares"])
            final["VPA"] = final["totalStockholderEquity"]/final["amount_shares"]
            final["VM"] = final["amount_shares"]*final["price_stock"]
            final["EV"] = final["VM"]+final["shortLongTermDebt"]-final["cash"]
            final["EV"] = final["VM"]+final["shortLongTermDebt"]-final["cash"]
            final["EV/EBIT"] = final["EV"]/final["ebit"]
            final["NOPAT"] = final["ebit"]-final["incomeTaxExpense"]
            final["ROIC"] = final["NOPAT"]/final["longTermInvestments"]
            final["formula-gharant"] = (final["VPA"]*final["LPA"]*22.5)**0.5
            final["margem-seguranca"] = (final["formula-gharant"]/final["price_stock"]-1)*100
        except TypeError:
            final.to_csv(fileName)
        except KeyError:
            final.to_csv(fileName)
        except IndexError:
            final.to_csv(fileName)
            
        
    
    except TypeError:
        continue
    except KeyError:
        continue
    except IndexError:
        continue
# Out:
# https://finance.yahoo.com/quote/AALR3.SA/financials?p=AALR3.SA <Response [200]>
# data-annual/AALR3.csv
# https://finance.yahoo.com/quote/ABCB4.SA/financials?p=ABCB4.SA <Response [200]>
# data-annual/ABCB4.csv
# https://finance.yahoo.com/quote/ABEV3.SA/financials?p=ABEV3.SA <Response [200]>
# data-annual/ABEV3.csv
# https://finance.yahoo.com/quote/AERI3.SA/financials?p=AERI3.SA <Response [200]>
# data-annual/AERI3.csv
# https://finance.yahoo.com/quote/AESB3.SA/financials?p=AESB3.SA <Response [200]>
# https://finance.yahoo.com/quote/AGRO3.SA/financials?p=AGRO3.SA <Response [200]>
# data-annual/AGRO3.csv
# https://finance.yahoo.com/quote/AGXY3.SA/financials?p=AGXY3.SA <Response [200]>
# data-annual/AGXY3.csv
# https://finance.yahoo.com/quote/ALLD3.SA/financials?p=ALLD3.SA <Response [200]>
# data-annual/ALLD3.csv
# https://finance.yahoo.com/quote/ALPA4.SA/financials?p=ALPA4.SA <Response [200]>
# data-annual/ALPA4.csv
# https://finance.yahoo.com/quote/ALPK3.SA/financials?p=ALPK3.SA <Response [200]>
# data-annual/ALPK3.csv
# https://finance.yahoo.com/quote/ALSO3.SA/financials?p=ALSO3.SA <Response [200]>
# data-annual/ALSO3.csv
# https://finance.yahoo.com/quote/ALUP11.SA/financials?p=ALUP11.SA <Response [200]>
# data-annual/ALUP11.csv
# https://finance.yahoo.com/quote/AMAR3.SA/financials?p=AMAR3.SA <Response [200]>
# data-annual/AMAR3.csv
# https://finance.yahoo.com/quote/AMBP3.SA/financials?p=AMBP3.SA <Response [200]>
# data-annual/AMBP3.csv
# https://finance.yahoo.com/quote/AMER3.SA/financials?p=AMER3.SA <Response [200]>
# data-annual/AMER3.csv
# https://finance.yahoo.com/quote/ANIM3.SA/financials?p=ANIM3.SA <Response [200]>
# data-annual/ANIM3.csv
# https://finance.yahoo.com/quote/APER3.SA/financials?p=APER3.SA <Response [200]>
# data-annual/APER3.csv
# https://finance.yahoo.com/quote/ARML3.SA/financials?p=ARML3.SA <Response [200]>
# data-annual/ARML3.csv
# https://finance.yahoo.com/quote/ARZZ3.SA/financials?p=ARZZ3.SA <Response [200]>
# data-annual/ARZZ3.csv
# https://finance.yahoo.com/quote/ASAI3.SA/financials?p=ASAI3.SA <Response [200]>
# data-annual/ASAI3.csv
# https://finance.yahoo.com/quote/AURA33.SA/financials?p=AURA33.SA <Response [200]>
# data-annual/AURA33.csv
# https://finance.yahoo.com/quote/AURE3.SA/financials?p=AURE3.SA <Response [200]>
# data-annual/AURE3.csv
# https://finance.yahoo.com/quote/AZEV3.SA/financials?p=AZEV3.SA <Response [200]>
# data-annual/AZEV3.csv
# https://finance.yahoo.com/quote/AZEV4.SA/financials?p=AZEV4.SA <Response [200]>
# data-annual/AZEV4.csv
# https://finance.yahoo.com/quote/AZUL4.SA/financials?p=AZUL4.SA <Response [200]>
# data-annual/AZUL4.csv
# https://finance.yahoo.com/quote/B3SA3.SA/financials?p=B3SA3.SA <Response [200]>
# data-annual/B3SA3.csv
# https://finance.yahoo.com/quote/BBAS3.SA/financials?p=BBAS3.SA <Response [200]>
# data-annual/BBAS3.csv
# https://finance.yahoo.com/quote/BBDC3.SA/financials?p=BBDC3.SA <Response [200]>
# data-annual/BBDC3.csv
# https://finance.yahoo.com/quote/BBDC4.SA/financials?p=BBDC4.SA <Response [200]>
# data-annual/BBDC4.csv
# https://finance.yahoo.com/quote/BBSE3.SA/financials?p=BBSE3.SA <Response [200]>
# data-annual/BBSE3.csv
# https://finance.yahoo.com/quote/BEEF3.SA/financials?p=BEEF3.SA <Response [200]>
# data-annual/BEEF3.csv
# https://finance.yahoo.com/quote/BIDI11.SA/financials?p=BIDI11.SA <Response [200]>
# https://finance.yahoo.com/quote/BIDI3.SA/financials?p=BIDI3.SA <Response [200]>
# data-annual/BIDI3.csv
# https://finance.yahoo.com/quote/BIDI4.SA/financials?p=BIDI4.SA <Response [200]>
# data-annual/BIDI4.csv
# https://finance.yahoo.com/quote/BKBR3.SA/financials?p=BKBR3.SA <Response [200]>
# data-annual/BKBR3.csv
# https://finance.yahoo.com/quote/BLAU3.SA/financials?p=BLAU3.SA <Response [200]>
# data-annual/BLAU3.csv
# https://finance.yahoo.com/quote/BMGB4.SA/financials?p=BMGB4.SA <Response [200]>
# data-annual/BMGB4.csv
# https://finance.yahoo.com/quote/BMOB3.SA/financials?p=BMOB3.SA <Response [200]>
# data-annual/BMOB3.csv
# https://finance.yahoo.com/quote/BOAS3.SA/financials?p=BOAS3.SA <Response [200]>
# data-annual/BOAS3.csv
# https://finance.yahoo.com/quote/BPAC11.SA/financials?p=BPAC11.SA <Response [200]>
# data-annual/BPAC11.csv
# https://finance.yahoo.com/quote/BPAN4.SA/financials?p=BPAN4.SA <Response [200]>
# data-annual/BPAN4.csv
# https://finance.yahoo.com/quote/BRAP3.SA/financials?p=BRAP3.SA <Response [200]>
# data-annual/BRAP3.csv
# https://finance.yahoo.com/quote/BRAP4.SA/financials?p=BRAP4.SA <Response [200]>
# data-annual/BRAP4.csv
# https://finance.yahoo.com/quote/BRBI11.SA/financials?p=BRBI11.SA <Response [200]>
# https://finance.yahoo.com/quote/BRFS3.SA/financials?p=BRFS3.SA <Response [200]>
# data-annual/BRFS3.csv
# https://finance.yahoo.com/quote/BRIT3.SA/financials?p=BRIT3.SA <Response [200]>
# data-annual/BRIT3.csv
# https://finance.yahoo.com/quote/BRKM3.SA/financials?p=BRKM3.SA <Response [200]>
# data-annual/BRKM3.csv
# https://finance.yahoo.com/quote/BRKM5.SA/financials?p=BRKM5.SA <Response [200]>
# data-annual/BRKM5.csv
# https://finance.yahoo.com/quote/BRML3.SA/financials?p=BRML3.SA <Response [200]>
# data-annual/BRML3.csv
# https://finance.yahoo.com/quote/BRPR3.SA/financials?p=BRPR3.SA <Response [200]>
# data-annual/BRPR3.csv
# https://finance.yahoo.com/quote/BRSR6.SA/financials?p=BRSR6.SA <Response [200]>
# data-annual/BRSR6.csv
# https://finance.yahoo.com/quote/CAML3.SA/financials?p=CAML3.SA <Response [200]>
# data-annual/CAML3.csv
# https://finance.yahoo.com/quote/CARD3.SA/financials?p=CARD3.SA <Response [200]>
# data-annual/CARD3.csv
# https://finance.yahoo.com/quote/CASH3.SA/financials?p=CASH3.SA <Response [200]>
# data-annual/CASH3.csv
# https://finance.yahoo.com/quote/CBAV3.SA/financials?p=CBAV3.SA <Response [200]>
# data-annual/CBAV3.csv
# https://finance.yahoo.com/quote/CCRO3.SA/financials?p=CCRO3.SA <Response [200]>
# data-annual/CCRO3.csv
# https://finance.yahoo.com/quote/CEAB3.SA/financials?p=CEAB3.SA <Response [200]>
# data-annual/CEAB3.csv
# https://finance.yahoo.com/quote/CESP6.SA/financials?p=CESP6.SA <Response [200]>
# https://finance.yahoo.com/quote/CGRA4.SA/financials?p=CGRA4.SA <Response [200]>
# data-annual/CGRA4.csv
# https://finance.yahoo.com/quote/CIEL3.SA/financials?p=CIEL3.SA <Response [200]>
# data-annual/CIEL3.csv
# https://finance.yahoo.com/quote/CLSA3.SA/financials?p=CLSA3.SA <Response [200]>
# data-annual/CLSA3.csv
# https://finance.yahoo.com/quote/CLSC4.SA/financials?p=CLSC4.SA <Response [200]>
# data-annual/CLSC4.csv
# https://finance.yahoo.com/quote/CMIG3.SA/financials?p=CMIG3.SA <Response [200]>
# data-annual/CMIG3.csv
# https://finance.yahoo.com/quote/CMIG4.SA/financials?p=CMIG4.SA <Response [200]>
# data-annual/CMIG4.csv
# https://finance.yahoo.com/quote/CMIN3.SA/financials?p=CMIN3.SA <Response [200]>
# data-annual/CMIN3.csv
# https://finance.yahoo.com/quote/COCE5.SA/financials?p=COCE5.SA <Response [200]>
# data-annual/COCE5.csv
# https://finance.yahoo.com/quote/COGN3.SA/financials?p=COGN3.SA <Response [200]>
# data-annual/COGN3.csv
# https://finance.yahoo.com/quote/CPFE3.SA/financials?p=CPFE3.SA <Response [200]>
# data-annual/CPFE3.csv
# https://finance.yahoo.com/quote/CPLE11.SA/financials?p=CPLE11.SA <Response [200]>
# data-annual/CPLE11.csv
# https://finance.yahoo.com/quote/CPLE3.SA/financials?p=CPLE3.SA <Response [200]>
# data-annual/CPLE3.csv
# https://finance.yahoo.com/quote/CPLE6.SA/financials?p=CPLE6.SA <Response [200]>
# data-annual/CPLE6.csv
# https://finance.yahoo.com/quote/CRFB3.SA/financials?p=CRFB3.SA <Response [200]>
# data-annual/CRFB3.csv
# https://finance.yahoo.com/quote/CSAN3.SA/financials?p=CSAN3.SA <Response [200]>
# data-annual/CSAN3.csv
# https://finance.yahoo.com/quote/CSED3.SA/financials?p=CSED3.SA <Response [200]>
# data-annual/CSED3.csv
# https://finance.yahoo.com/quote/CSMG3.SA/financials?p=CSMG3.SA <Response [200]>
# data-annual/CSMG3.csv
# https://finance.yahoo.com/quote/CSNA3.SA/financials?p=CSNA3.SA <Response [200]>
# data-annual/CSNA3.csv
# https://finance.yahoo.com/quote/CURY3.SA/financials?p=CURY3.SA <Response [200]>
# data-annual/CURY3.csv
# https://finance.yahoo.com/quote/CVCB3.SA/financials?p=CVCB3.SA <Response [200]>
# data-annual/CVCB3.csv
# https://finance.yahoo.com/quote/CXSE3.SA/financials?p=CXSE3.SA <Response [200]>
# data-annual/CXSE3.csv
# https://finance.yahoo.com/quote/CYRE3.SA/financials?p=CYRE3.SA <Response [200]>
# data-annual/CYRE3.csv
# https://finance.yahoo.com/quote/DASA3.SA/financials?p=DASA3.SA <Response [200]>
# data-annual/DASA3.csv
# https://finance.yahoo.com/quote/DESK3.SA/financials?p=DESK3.SA <Response [200]>
# data-annual/DESK3.csv
# https://finance.yahoo.com/quote/DEXP3.SA/financials?p=DEXP3.SA <Response [200]>
# data-annual/DEXP3.csv
# https://finance.yahoo.com/quote/DIRR3.SA/financials?p=DIRR3.SA <Response [200]>
# data-annual/DIRR3.csv
# https://finance.yahoo.com/quote/DMMO3.SA/financials?p=DMMO3.SA <Response [200]>
# data-annual/DMMO3.csv
# https://finance.yahoo.com/quote/DMVF3.SA/financials?p=DMVF3.SA <Response [200]>
# data-annual/DMVF3.csv
# https://finance.yahoo.com/quote/DXCO3.SA/financials?p=DXCO3.SA <Response [200]>
# data-annual/DXCO3.csv
# https://finance.yahoo.com/quote/ECOR3.SA/financials?p=ECOR3.SA <Response [200]>
# data-annual/ECOR3.csv
# https://finance.yahoo.com/quote/EGIE3.SA/financials?p=EGIE3.SA <Response [200]>
# data-annual/EGIE3.csv
# https://finance.yahoo.com/quote/ELET3.SA/financials?p=ELET3.SA <Response [200]>
# data-annual/ELET3.csv
# https://finance.yahoo.com/quote/ELET6.SA/financials?p=ELET6.SA <Response [200]>
# data-annual/ELET6.csv
# https://finance.yahoo.com/quote/ELMD3.SA/financials?p=ELMD3.SA <Response [200]>
# data-annual/ELMD3.csv
# https://finance.yahoo.com/quote/EMBR3.SA/financials?p=EMBR3.SA <Response [200]>
# data-annual/EMBR3.csv
# https://finance.yahoo.com/quote/ENAT3.SA/financials?p=ENAT3.SA <Response [200]>
# data-annual/ENAT3.csv
# https://finance.yahoo.com/quote/ENBR3.SA/financials?p=ENBR3.SA <Response [200]>
# data-annual/ENBR3.csv
# https://finance.yahoo.com/quote/ENEV3.SA/financials?p=ENEV3.SA <Response [200]>
# data-annual/ENEV3.csv
# https://finance.yahoo.com/quote/ENGI11.SA/financials?p=ENGI11.SA <Response [200]>
# data-annual/ENGI11.csv
# https://finance.yahoo.com/quote/ENJU3.SA/financials?p=ENJU3.SA <Response [200]>
# data-annual/ENJU3.csv
# https://finance.yahoo.com/quote/EQTL3.SA/financials?p=EQTL3.SA <Response [200]>
# data-annual/EQTL3.csv
# https://finance.yahoo.com/quote/ESPA3.SA/financials?p=ESPA3.SA <Response [200]>
# data-annual/ESPA3.csv
# https://finance.yahoo.com/quote/ETER3.SA/financials?p=ETER3.SA <Response [200]>
# data-annual/ETER3.csv
# https://finance.yahoo.com/quote/EUCA4.SA/financials?p=EUCA4.SA <Response [200]>
# data-annual/EUCA4.csv
# https://finance.yahoo.com/quote/EVEN3.SA/financials?p=EVEN3.SA <Response [200]>
# data-annual/EVEN3.csv
# https://finance.yahoo.com/quote/EZTC3.SA/financials?p=EZTC3.SA <Response [200]>
# data-annual/EZTC3.csv
# https://finance.yahoo.com/quote/FESA4.SA/financials?p=FESA4.SA <Response [200]>
# data-annual/FESA4.csv
# https://finance.yahoo.com/quote/FHER3.SA/financials?p=FHER3.SA <Response [200]>
# data-annual/FHER3.csv
# https://finance.yahoo.com/quote/FIQE3.SA/financials?p=FIQE3.SA <Response [200]>
# data-annual/FIQE3.csv
# https://finance.yahoo.com/quote/FLRY3.SA/financials?p=FLRY3.SA <Response [200]>
# data-annual/FLRY3.csv
# https://finance.yahoo.com/quote/FRAS3.SA/financials?p=FRAS3.SA <Response [200]>
# data-annual/FRAS3.csv
# https://finance.yahoo.com/quote/G2DI33.SA/financials?p=G2DI33.SA <Response [200]>
# https://finance.yahoo.com/quote/GETT11.SA/financials?p=GETT11.SA <Response [200]>
# https://finance.yahoo.com/quote/GFSA3.SA/financials?p=GFSA3.SA <Response [200]>
# data-annual/GFSA3.csv
# https://finance.yahoo.com/quote/GGBR3.SA/financials?p=GGBR3.SA <Response [200]>
# data-annual/GGBR3.csv
# https://finance.yahoo.com/quote/GGBR4.SA/financials?p=GGBR4.SA <Response [200]>
# data-annual/GGBR4.csv
# https://finance.yahoo.com/quote/GGPS3.SA/financials?p=GGPS3.SA <Response [200]>
# data-annual/GGPS3.csv
# https://finance.yahoo.com/quote/GMAT3.SA/financials?p=GMAT3.SA <Response [200]>
# data-annual/GMAT3.csv
# https://finance.yahoo.com/quote/GNDI3.SA/financials?p=GNDI3.SA <Response [200]>
# https://finance.yahoo.com/quote/GOAU3.SA/financials?p=GOAU3.SA <Response [200]>
# data-annual/GOAU3.csv
# https://finance.yahoo.com/quote/GOAU4.SA/financials?p=GOAU4.SA <Response [200]>
# data-annual/GOAU4.csv
# https://finance.yahoo.com/quote/GOLL4.SA/financials?p=GOLL4.SA <Response [200]>
# data-annual/GOLL4.csv
# https://finance.yahoo.com/quote/GRND3.SA/financials?p=GRND3.SA <Response [200]>
# data-annual/GRND3.csv
# https://finance.yahoo.com/quote/GUAR3.SA/financials?p=GUAR3.SA <Response [200]>
# data-annual/GUAR3.csv
# https://finance.yahoo.com/quote/HAPV3.SA/financials?p=HAPV3.SA <Response [200]>
# data-annual/HAPV3.csv
# https://finance.yahoo.com/quote/HBOR3.SA/financials?p=HBOR3.SA <Response [200]>
# data-annual/HBOR3.csv
# https://finance.yahoo.com/quote/HBRE3.SA/financials?p=HBRE3.SA <Response [200]>
# data-annual/HBRE3.csv
# https://finance.yahoo.com/quote/HBSA3.SA/financials?p=HBSA3.SA <Response [200]>
# data-annual/HBSA3.csv
# https://finance.yahoo.com/quote/HGTX3.SA/financials?p=HGTX3.SA <Response [200]>
# https://finance.yahoo.com/quote/HYPE3.SA/financials?p=HYPE3.SA <Response [200]>
# data-annual/HYPE3.csv
# https://finance.yahoo.com/quote/IFCM3.SA/financials?p=IFCM3.SA <Response [200]>
# data-annual/IFCM3.csv
# https://finance.yahoo.com/quote/IGTA3.SA/financials?p=IGTA3.SA <Response [200]>
# https://finance.yahoo.com/quote/IGTI11.SA/financials?p=IGTI11.SA <Response [200]>
# https://finance.yahoo.com/quote/IGTI3.SA/financials?p=IGTI3.SA <Response [200]>
# data-annual/IGTI3.csv
# https://finance.yahoo.com/quote/INEP3.SA/financials?p=INEP3.SA <Response [200]>
# data-annual/INEP3.csv
# https://finance.yahoo.com/quote/INEP4.SA/financials?p=INEP4.SA <Response [200]>
# data-annual/INEP4.csv
# https://finance.yahoo.com/quote/INTB3.SA/financials?p=INTB3.SA <Response [200]>
# data-annual/INTB3.csv
# https://finance.yahoo.com/quote/IRBR3.SA/financials?p=IRBR3.SA <Response [200]>
# data-annual/IRBR3.csv
# https://finance.yahoo.com/quote/ITSA3.SA/financials?p=ITSA3.SA <Response [200]>
# data-annual/ITSA3.csv
# https://finance.yahoo.com/quote/ITSA4.SA/financials?p=ITSA4.SA <Response [200]>
# data-annual/ITSA4.csv
# https://finance.yahoo.com/quote/ITUB3.SA/financials?p=ITUB3.SA <Response [200]>
# data-annual/ITUB3.csv
# https://finance.yahoo.com/quote/ITUB4.SA/financials?p=ITUB4.SA <Response [200]>
# data-annual/ITUB4.csv
# https://finance.yahoo.com/quote/JALL3.SA/financials?p=JALL3.SA <Response [200]>
# data-annual/JALL3.csv
# https://finance.yahoo.com/quote/JBSS3.SA/financials?p=JBSS3.SA <Response [200]>
# data-annual/JBSS3.csv
# https://finance.yahoo.com/quote/JHSF3.SA/financials?p=JHSF3.SA <Response [200]>
# data-annual/JHSF3.csv
# https://finance.yahoo.com/quote/JSLG3.SA/financials?p=JSLG3.SA <Response [200]>
# data-annual/JSLG3.csv
# https://finance.yahoo.com/quote/KEPL3.SA/financials?p=KEPL3.SA <Response [200]>
# data-annual/KEPL3.csv
# https://finance.yahoo.com/quote/KLBN11.SA/financials?p=KLBN11.SA <Response [200]>
# data-annual/KLBN11.csv
# https://finance.yahoo.com/quote/KLBN3.SA/financials?p=KLBN3.SA <Response [200]>
# data-annual/KLBN3.csv
# https://finance.yahoo.com/quote/KLBN4.SA/financials?p=KLBN4.SA <Response [200]>
# data-annual/KLBN4.csv
# https://finance.yahoo.com/quote/KRSA3.SA/financials?p=KRSA3.SA <Response [200]>
# data-annual/KRSA3.csv
# https://finance.yahoo.com/quote/LAME3.SA/financials?p=LAME3.SA <Response [200]>
# https://finance.yahoo.com/quote/LAME4.SA/financials?p=LAME4.SA <Response [200]>
# https://finance.yahoo.com/quote/LAND3.SA/financials?p=LAND3.SA <Response [200]>
# https://finance.yahoo.com/quote/LAVV3.SA/financials?p=LAVV3.SA <Response [200]>
# data-annual/LAVV3.csv
# https://finance.yahoo.com/quote/LCAM3.SA/financials?p=LCAM3.SA <Response [200]>
# data-annual/LCAM3.csv
# https://finance.yahoo.com/quote/LEVE3.SA/financials?p=LEVE3.SA <Response [200]>
# data-annual/LEVE3.csv
# https://finance.yahoo.com/quote/LIGT3.SA/financials?p=LIGT3.SA <Response [200]>
# data-annual/LIGT3.csv
# https://finance.yahoo.com/quote/LJQQ3.SA/financials?p=LJQQ3.SA <Response [200]>
# data-annual/LJQQ3.csv
# https://finance.yahoo.com/quote/LLIS3.SA/financials?p=LLIS3.SA <Response [200]>
# data-annual/LLIS3.csv
# https://finance.yahoo.com/quote/LOGG3.SA/financials?p=LOGG3.SA <Response [200]>
# data-annual/LOGG3.csv
# https://finance.yahoo.com/quote/LOGN3.SA/financials?p=LOGN3.SA <Response [200]>
# data-annual/LOGN3.csv
# https://finance.yahoo.com/quote/LPSB3.SA/financials?p=LPSB3.SA <Response [200]>
# data-annual/LPSB3.csv
# https://finance.yahoo.com/quote/LREN3.SA/financials?p=LREN3.SA <Response [200]>
# data-annual/LREN3.csv
# https://finance.yahoo.com/quote/LUPA3.SA/financials?p=LUPA3.SA <Response [200]>
# data-annual/LUPA3.csv
# https://finance.yahoo.com/quote/LVTC3.SA/financials?p=LVTC3.SA <Response [200]>
# data-annual/LVTC3.csv
# https://finance.yahoo.com/quote/LWSA3.SA/financials?p=LWSA3.SA <Response [200]>
# data-annual/LWSA3.csv
# https://finance.yahoo.com/quote/MATD3.SA/financials?p=MATD3.SA <Response [200]>
# data-annual/MATD3.csv
# https://finance.yahoo.com/quote/MBLY3.SA/financials?p=MBLY3.SA <Response [200]>
# data-annual/MBLY3.csv
# https://finance.yahoo.com/quote/MDIA3.SA/financials?p=MDIA3.SA <Response [200]>
# data-annual/MDIA3.csv
# https://finance.yahoo.com/quote/MDNE3.SA/financials?p=MDNE3.SA <Response [200]>
# data-annual/MDNE3.csv
# https://finance.yahoo.com/quote/MEAL3.SA/financials?p=MEAL3.SA <Response [200]>
# data-annual/MEAL3.csv
# https://finance.yahoo.com/quote/MEGA3.SA/financials?p=MEGA3.SA <Response [200]>
# data-annual/MEGA3.csv
# https://finance.yahoo.com/quote/MELK3.SA/financials?p=MELK3.SA <Response [200]>
# data-annual/MELK3.csv
# https://finance.yahoo.com/quote/MGLU3.SA/financials?p=MGLU3.SA <Response [200]>
# data-annual/MGLU3.csv
# https://finance.yahoo.com/quote/MILS3.SA/financials?p=MILS3.SA <Response [200]>
# data-annual/MILS3.csv
# https://finance.yahoo.com/quote/MLAS3.SA/financials?p=MLAS3.SA <Response [200]>
# data-annual/MLAS3.csv
# https://finance.yahoo.com/quote/MOAR3.SA/financials?p=MOAR3.SA <Response [200]>
# data-annual/MOAR3.csv
# https://finance.yahoo.com/quote/MODL11.SA/financials?p=MODL11.SA <Response [200]>
# data-annual/MODL11.csv
# https://finance.yahoo.com/quote/MOSI3.SA/financials?p=MOSI3.SA <Response [200]>
# https://finance.yahoo.com/quote/MOVI3.SA/financials?p=MOVI3.SA <Response [200]>
# data-annual/MOVI3.csv
# https://finance.yahoo.com/quote/MRFG3.SA/financials?p=MRFG3.SA <Response [200]>
# data-annual/MRFG3.csv
# https://finance.yahoo.com/quote/MRVE3.SA/financials?p=MRVE3.SA <Response [200]>
# data-annual/MRVE3.csv
# https://finance.yahoo.com/quote/MTRE3.SA/financials?p=MTRE3.SA <Response [200]>
# data-annual/MTRE3.csv
# https://finance.yahoo.com/quote/MULT3.SA/financials?p=MULT3.SA <Response [200]>
# data-annual/MULT3.csv
# https://finance.yahoo.com/quote/MYPK3.SA/financials?p=MYPK3.SA <Response [200]>
# data-annual/MYPK3.csv
# https://finance.yahoo.com/quote/NEOE3.SA/financials?p=NEOE3.SA <Response [200]>
# data-annual/NEOE3.csv
# https://finance.yahoo.com/quote/NGRD3.SA/financials?p=NGRD3.SA <Response [200]>
# data-annual/NGRD3.csv
# https://finance.yahoo.com/quote/NINJ3.SA/financials?p=NINJ3.SA <Response [200]>
# data-annual/NINJ3.csv
# https://finance.yahoo.com/quote/NTCO3.SA/financials?p=NTCO3.SA <Response [200]>
# data-annual/NTCO3.csv
# https://finance.yahoo.com/quote/ODPV3.SA/financials?p=ODPV3.SA <Response [200]>
# data-annual/ODPV3.csv
# https://finance.yahoo.com/quote/OFSA3.SA/financials?p=OFSA3.SA <Response [200]>
# data-annual/OFSA3.csv
# https://finance.yahoo.com/quote/OIBR3.SA/financials?p=OIBR3.SA <Response [200]>
# data-annual/OIBR3.csv
# https://finance.yahoo.com/quote/OIBR4.SA/financials?p=OIBR4.SA <Response [200]>
# data-annual/OIBR4.csv
# https://finance.yahoo.com/quote/OMGE3.SA/financials?p=OMGE3.SA <Response [200]>
# https://finance.yahoo.com/quote/ONCO3.SA/financials?p=ONCO3.SA <Response [200]>
# data-annual/ONCO3.csv
# https://finance.yahoo.com/quote/OPCT3.SA/financials?p=OPCT3.SA <Response [200]>
# data-annual/OPCT3.csv
# https://finance.yahoo.com/quote/ORVR3.SA/financials?p=ORVR3.SA <Response [200]>
# data-annual/ORVR3.csv
# https://finance.yahoo.com/quote/PARD3.SA/financials?p=PARD3.SA <Response [200]>
# data-annual/PARD3.csv
# https://finance.yahoo.com/quote/PCAR3.SA/financials?p=PCAR3.SA <Response [200]>
# data-annual/PCAR3.csv
# https://finance.yahoo.com/quote/PDGR3.SA/financials?p=PDGR3.SA <Response [200]>
# data-annual/PDGR3.csv
# https://finance.yahoo.com/quote/PETR3.SA/financials?p=PETR3.SA <Response [200]>
# data-annual/PETR3.csv
# https://finance.yahoo.com/quote/PETR4.SA/financials?p=PETR4.SA <Response [200]>
# data-annual/PETR4.csv
# https://finance.yahoo.com/quote/PETZ3.SA/financials?p=PETZ3.SA <Response [200]>
# data-annual/PETZ3.csv
# https://finance.yahoo.com/quote/PFRM3.SA/financials?p=PFRM3.SA <Response [200]>
# data-annual/PFRM3.csv
# https://finance.yahoo.com/quote/PGMN3.SA/financials?p=PGMN3.SA <Response [200]>
# data-annual/PGMN3.csv
# https://finance.yahoo.com/quote/PLPL3.SA/financials?p=PLPL3.SA <Response [200]>
# data-annual/PLPL3.csv
# https://finance.yahoo.com/quote/PMAM3.SA/financials?p=PMAM3.SA <Response [200]>
# data-annual/PMAM3.csv
# https://finance.yahoo.com/quote/PNVL3.SA/financials?p=PNVL3.SA <Response [200]>
# data-annual/PNVL3.csv
# https://finance.yahoo.com/quote/POMO4.SA/financials?p=POMO4.SA <Response [200]>
# data-annual/POMO4.csv
# https://finance.yahoo.com/quote/PORT3.SA/financials?p=PORT3.SA <Response [200]>
# data-annual/PORT3.csv
# https://finance.yahoo.com/quote/POSI3.SA/financials?p=POSI3.SA <Response [200]>
# data-annual/POSI3.csv
# https://finance.yahoo.com/quote/POWE3.SA/financials?p=POWE3.SA <Response [200]>
# https://finance.yahoo.com/quote/PRIO3.SA/financials?p=PRIO3.SA <Response [200]>
# data-annual/PRIO3.csv
# https://finance.yahoo.com/quote/PRNR3.SA/financials?p=PRNR3.SA <Response [200]>
# data-annual/PRNR3.csv
# https://finance.yahoo.com/quote/PSSA3.SA/financials?p=PSSA3.SA <Response [200]>
# data-annual/PSSA3.csv
# https://finance.yahoo.com/quote/PTBL3.SA/financials?p=PTBL3.SA <Response [200]>
# data-annual/PTBL3.csv
# https://finance.yahoo.com/quote/QUAL3.SA/financials?p=QUAL3.SA <Response [200]>
# data-annual/QUAL3.csv
# https://finance.yahoo.com/quote/RADL3.SA/financials?p=RADL3.SA <Response [200]>
# data-annual/RADL3.csv
# https://finance.yahoo.com/quote/RAIL3.SA/financials?p=RAIL3.SA <Response [200]>
# data-annual/RAIL3.csv
# https://finance.yahoo.com/quote/RAIZ4.SA/financials?p=RAIZ4.SA <Response [200]>
# data-annual/RAIZ4.csv
# https://finance.yahoo.com/quote/RANI3.SA/financials?p=RANI3.SA <Response [200]>
# data-annual/RANI3.csv
# https://finance.yahoo.com/quote/RAPT4.SA/financials?p=RAPT4.SA <Response [200]>
# data-annual/RAPT4.csv
# https://finance.yahoo.com/quote/RCSL3.SA/financials?p=RCSL3.SA <Response [200]>
# data-annual/RCSL3.csv
# https://finance.yahoo.com/quote/RCSL4.SA/financials?p=RCSL4.SA <Response [200]>
# data-annual/RCSL4.csv
# https://finance.yahoo.com/quote/RDOR3.SA/financials?p=RDOR3.SA <Response [200]>
# data-annual/RDOR3.csv
# https://finance.yahoo.com/quote/RECV3.SA/financials?p=RECV3.SA <Response [200]>
# data-annual/RECV3.csv
# https://finance.yahoo.com/quote/RENT3.SA/financials?p=RENT3.SA <Response [200]>
# data-annual/RENT3.csv
# https://finance.yahoo.com/quote/RNEW3.SA/financials?p=RNEW3.SA <Response [200]>
# data-annual/RNEW3.csv
# https://finance.yahoo.com/quote/RNEW4.SA/financials?p=RNEW4.SA <Response [200]>
# data-annual/RNEW4.csv
# https://finance.yahoo.com/quote/ROMI3.SA/financials?p=ROMI3.SA <Response [200]>
# data-annual/ROMI3.csv
# https://finance.yahoo.com/quote/RRRP3.SA/financials?p=RRRP3.SA <Response [200]>
# data-annual/RRRP3.csv
# https://finance.yahoo.com/quote/RSID3.SA/financials?p=RSID3.SA <Response [200]>
# data-annual/RSID3.csv
# https://finance.yahoo.com/quote/SANB11.SA/financials?p=SANB11.SA <Response [200]>
# data-annual/SANB11.csv
# https://finance.yahoo.com/quote/SANB3.SA/financials?p=SANB3.SA <Response [200]>
# data-annual/SANB3.csv
# https://finance.yahoo.com/quote/SANB4.SA/financials?p=SANB4.SA <Response [200]>
# data-annual/SANB4.csv
# https://finance.yahoo.com/quote/SAPR11.SA/financials?p=SAPR11.SA <Response [200]>
# data-annual/SAPR11.csv
# https://finance.yahoo.com/quote/SAPR3.SA/financials?p=SAPR3.SA <Response [200]>
# data-annual/SAPR3.csv
# https://finance.yahoo.com/quote/SAPR4.SA/financials?p=SAPR4.SA <Response [200]>
# data-annual/SAPR4.csv
# https://finance.yahoo.com/quote/SBFG3.SA/financials?p=SBFG3.SA <Response [200]>
# data-annual/SBFG3.csv
# https://finance.yahoo.com/quote/SBSP3.SA/financials?p=SBSP3.SA <Response [200]>
# data-annual/SBSP3.csv
# https://finance.yahoo.com/quote/SEER3.SA/financials?p=SEER3.SA <Response [200]>
# data-annual/SEER3.csv
# https://finance.yahoo.com/quote/SEQL3.SA/financials?p=SEQL3.SA <Response [200]>
# data-annual/SEQL3.csv
# https://finance.yahoo.com/quote/SHOW3.SA/financials?p=SHOW3.SA <Response [200]>
# data-annual/SHOW3.csv
# https://finance.yahoo.com/quote/SHUL4.SA/financials?p=SHUL4.SA <Response [200]>
# data-annual/SHUL4.csv
# https://finance.yahoo.com/quote/SIMH3.SA/financials?p=SIMH3.SA <Response [200]>
# data-annual/SIMH3.csv
# https://finance.yahoo.com/quote/SLCE3.SA/financials?p=SLCE3.SA <Response [200]>
# data-annual/SLCE3.csv
# https://finance.yahoo.com/quote/SMFT3.SA/financials?p=SMFT3.SA <Response [200]>
# data-annual/SMFT3.csv
# https://finance.yahoo.com/quote/SMTO3.SA/financials?p=SMTO3.SA <Response [200]>
# data-annual/SMTO3.csv
# https://finance.yahoo.com/quote/SOJA3.SA/financials?p=SOJA3.SA <Response [200]>
# https://finance.yahoo.com/quote/SOMA3.SA/financials?p=SOMA3.SA <Response [200]>
# data-annual/SOMA3.csv
# https://finance.yahoo.com/quote/SQIA3.SA/financials?p=SQIA3.SA <Response [200]>
# data-annual/SQIA3.csv
# https://finance.yahoo.com/quote/STBP3.SA/financials?p=STBP3.SA <Response [200]>
# data-annual/STBP3.csv
# https://finance.yahoo.com/quote/SULA11.SA/financials?p=SULA11.SA <Response [200]>
# data-annual/SULA11.csv
# https://finance.yahoo.com/quote/SUZB3.SA/financials?p=SUZB3.SA <Response [200]>
# data-annual/SUZB3.csv
# https://finance.yahoo.com/quote/SYNE3.SA/financials?p=SYNE3.SA <Response [200]>
# data-annual/SYNE3.csv
# https://finance.yahoo.com/quote/TAEE11.SA/financials?p=TAEE11.SA <Response [200]>
# data-annual/TAEE11.csv
# https://finance.yahoo.com/quote/TAEE3.SA/financials?p=TAEE3.SA <Response [200]>
# data-annual/TAEE3.csv
# https://finance.yahoo.com/quote/TAEE4.SA/financials?p=TAEE4.SA <Response [200]>
# data-annual/TAEE4.csv
# https://finance.yahoo.com/quote/TASA3.SA/financials?p=TASA3.SA <Response [200]>
# data-annual/TASA3.csv
# https://finance.yahoo.com/quote/TASA4.SA/financials?p=TASA4.SA <Response [200]>
# data-annual/TASA4.csv
# https://finance.yahoo.com/quote/TCSA3.SA/financials?p=TCSA3.SA <Response [200]>
# data-annual/TCSA3.csv
# https://finance.yahoo.com/quote/TECN3.SA/financials?p=TECN3.SA <Response [200]>
# data-annual/TECN3.csv
# https://finance.yahoo.com/quote/TEND3.SA/financials?p=TEND3.SA <Response [200]>
# data-annual/TEND3.csv
# https://finance.yahoo.com/quote/TFCO4.SA/financials?p=TFCO4.SA <Response [200]>
# https://finance.yahoo.com/quote/TGMA3.SA/financials?p=TGMA3.SA <Response [200]>
# data-annual/TGMA3.csv
# https://finance.yahoo.com/quote/TIMS3.SA/financials?p=TIMS3.SA <Response [200]>
# data-annual/TIMS3.csv
# https://finance.yahoo.com/quote/TOTS3.SA/financials?p=TOTS3.SA <Response [200]>
# data-annual/TOTS3.csv
# https://finance.yahoo.com/quote/TPIS3.SA/financials?p=TPIS3.SA <Response [200]>
# data-annual/TPIS3.csv
# https://finance.yahoo.com/quote/TRAD3.SA/financials?p=TRAD3.SA <Response [200]>
# data-annual/TRAD3.csv
# https://finance.yahoo.com/quote/TRIS3.SA/financials?p=TRIS3.SA <Response [200]>
# data-annual/TRIS3.csv
# https://finance.yahoo.com/quote/TRPL4.SA/financials?p=TRPL4.SA <Response [200]>
# data-annual/TRPL4.csv
# https://finance.yahoo.com/quote/TTEN3.SA/financials?p=TTEN3.SA <Response [200]>
# data-annual/TTEN3.csv
# https://finance.yahoo.com/quote/TUPY3.SA/financials?p=TUPY3.SA <Response [200]>
# data-annual/TUPY3.csv
# https://finance.yahoo.com/quote/UCAS3.SA/financials?p=UCAS3.SA <Response [200]>
# data-annual/UCAS3.csv
# https://finance.yahoo.com/quote/UGPA3.SA/financials?p=UGPA3.SA <Response [200]>
# data-annual/UGPA3.csv
# https://finance.yahoo.com/quote/UNIP3.SA/financials?p=UNIP3.SA <Response [200]>
# data-annual/UNIP3.csv
# https://finance.yahoo.com/quote/UNIP6.SA/financials?p=UNIP6.SA <Response [200]>
# data-annual/UNIP6.csv
# https://finance.yahoo.com/quote/USIM3.SA/financials?p=USIM3.SA <Response [200]>
# data-annual/USIM3.csv
# https://finance.yahoo.com/quote/USIM5.SA/financials?p=USIM5.SA <Response [200]>
# data-annual/USIM5.csv
# https://finance.yahoo.com/quote/VALE3.SA/financials?p=VALE3.SA <Response [200]>
# data-annual/VALE3.csv
# https://finance.yahoo.com/quote/VAMO3.SA/financials?p=VAMO3.SA <Response [200]>
# data-annual/VAMO3.csv
# https://finance.yahoo.com/quote/VBBR3.SA/financials?p=VBBR3.SA <Response [200]>
# data-annual/VBBR3.csv
# https://finance.yahoo.com/quote/VIIA3.SA/financials?p=VIIA3.SA <Response [200]>
# data-annual/VIIA3.csv
# https://finance.yahoo.com/quote/VITT3.SA/financials?p=VITT3.SA <Response [200]>
# data-annual/VITT3.csv
# https://finance.yahoo.com/quote/VIVA3.SA/financials?p=VIVA3.SA <Response [200]>
# data-annual/VIVA3.csv
# https://finance.yahoo.com/quote/VIVR3.SA/financials?p=VIVR3.SA <Response [200]>
# data-annual/VIVR3.csv
# https://finance.yahoo.com/quote/VIVT3.SA/financials?p=VIVT3.SA <Response [200]>
# data-annual/VIVT3.csv
# https://finance.yahoo.com/quote/VLID3.SA/financials?p=VLID3.SA <Response [200]>
# data-annual/VLID3.csv
# https://finance.yahoo.com/quote/VULC3.SA/financials?p=VULC3.SA <Response [200]>
# data-annual/VULC3.csv
# https://finance.yahoo.com/quote/VVEO3.SA/financials?p=VVEO3.SA <Response [200]>
# data-annual/VVEO3.csv
# https://finance.yahoo.com/quote/WEGE3.SA/financials?p=WEGE3.SA <Response [200]>
# data-annual/WEGE3.csv
# https://finance.yahoo.com/quote/WEST3.SA/financials?p=WEST3.SA <Response [200]>
# data-annual/WEST3.csv
# https://finance.yahoo.com/quote/WIZS3.SA/financials?p=WIZS3.SA <Response [200]>
# data-annual/WIZS3.csv
# https://finance.yahoo.com/quote/YDUQ3.SA/financials?p=YDUQ3.SA <Response [200]>
# data-annual/YDUQ3.csv
