# %%
import pandas as pd
import numpy as np

pd.options.display.max_columns = None
#https://www.youtube.com/watch?v=jFCwNXAEGpA

# %%
#EV/EBIT 0,01
#Liquidez média diária 250.000,00
#Valor de mercado  250.000.000,00

data =  pd.read_csv('statusinvest-busca-avancada.csv', sep=';',encoding='latin-1')
columns = data.columns
columns
# Out:
# Index(['TICKER', 'PRECO', 'DY', 'P/L', 'P/VP', 'P/ATIVOS', 'MARGEM BRUTA',
#        'MARGEM EBIT', 'MARG. LIQUIDA', 'P/EBIT', 'EV/EBIT',
#        'DIVIDA LIQUIDA / EBIT', 'DIV. LIQ. / PATRI.', 'PSR', 'P/CAP. GIRO',
#        'P. AT CIR. LIQ.', 'LIQ. CORRENTE', 'ROE', 'ROA', 'ROIC',
#        'PATRIMONIO / ATIVOS', 'PASSIVOS / ATIVOS', 'GIRO ATIVOS',
#        'CAGR RECEITAS 5 ANOS', 'CAGR LUCROS 5 ANOS', ' LIQUIDEZ MEDIA DIARIA',
#        ' VPA', ' LPA', ' PEG Ratio', ' VALOR DE MERCADO'],
#       dtype='object')

# %%
cod = data['TICKER'].to_numpy()
len(cod)

# %%
data = data.sort_values(by=["EV/EBIT"])
data.head(10)
# Out:
#     TICKER  PRECO      DY    P/L   P/VP P/ATIVOS MARGEM BRUTA MARGEM EBIT  \
# 85   ENJU3   1,44     NaN  -2,72   0,74     0,65        30,49     -106,80
# 103  GOAU3  10,32   22,29   2,04   0,69     0,14        26,33       26,28
# 104  GOAU4  11,20   20,54   2,21   0,75     0,16        26,33       26,28
# 219  SYNE3   5,24  166,28   0,65   0,52     0,18        69,87       68,45
# 115  INEP3   1,88     NaN   0,29  -0,26     0,23        30,23    5.247,91
# 116  INEP4   1,72     NaN   0,27  -0,24     0,21        30,23    5.247,91
# 237  USIM3   8,29    9,02   1,72   0,44     0,25        27,12       22,57
# 238  USIM5   7,65   10,75   1,58   0,40     0,23        27,12       22,57
# 34   BRAP3  23,32   29,75   1,51   1,18     1,17          NaN         NaN
# 35   BRAP4  25,01   30,34   1,63   1,28     1,27          NaN         NaN
#
#     MARG. LIQUIDA P/EBIT EV/EBIT DIVIDA LIQUIDA / EBIT DIV. LIQ. / PATRI.  \
# 85         -86,00  -2,19    0,41                  2,60              -0,88
# 103          6,39   0,50    0,70                  0,18               0,25
# 104          6,39   0,54    0,70                  0,18               0,25
# 219         52,92   0,50    0,88                  0,37               0,38
# 115      4.710,27   0,26    0,93                  0,67                NaN
# 116      4.710,27   0,24    0,93                  0,67                NaN
# 237         18,09   1,38    1,39                  0,06               0,02
# 238         18,09   1,27    1,39                  0,06               0,02
# 34            NaN   1,54    1,56                 -0,05              -0,04
# 35            NaN   1,66    1,56                 -0,05              -0,04
#
#        PSR P/CAP. GIRO P. AT CIR. LIQ. LIQ. CORRENTE     ROE     ROA     ROIC  \
# 85    2,34        0,86           -4,52          7,98  -27,23  -23,86   -33,82
# 103   0,13        0,54           -0,27          2,26   33,85    7,03    29,17
# 104   0,14        0,58           -0,30          2,26   33,85    7,03    29,17
# 219   0,34        1,09           -0,23          4,43   79,85   27,77    38,27
# 115  13,87       -0,35           -0,25          0,10  -88,01   77,26  -281,01
# 116  12,69       -0,32           -0,22          0,10  -88,01   77,26  -281,01
# 237   0,31        0,67           -0,53          3,51   25,44   14,66    19,98
# 238   0,29        0,62           -0,49          3,51   25,44   14,66    19,98
# 34     NaN       35,37           -1,22          6,01   78,20   77,67    76,80
# 35     NaN       38,15           -1,32          6,01   78,20   77,67    76,80
#
#     PATRIMONIO / ATIVOS PASSIVOS / ATIVOS GIRO ATIVOS CAGR RECEITAS 5 ANOS  \
# 85                 0,88              0,12        0,28                  NaN
# 103                0,21              0,38        1,10                15,78
# 104                0,21              0,38        1,10                15,78
# 219                0,35              0,40        0,52                40,50
# 115               -0,88              1,88        0,02               -18,75
# 116               -0,88              1,88        0,02               -18,75
# 237                0,58              0,36        0,81                31,89
# 238                0,58              0,36        0,81                31,89
# 34                 0,99              0,01        0,00                  NaN
# 35                 0,99              0,01        0,00                  NaN
#
#     CAGR LUCROS 5 ANOS  LIQUIDEZ MEDIA DIARIA    VPA    LPA  PEG Ratio  \
# 85                 NaN           2.073.246,26   1,95  -0,53      -0,14
# 103                NaN             984.303,07  14,95   5,06       0,02
# 104                NaN         103.462.068,93  14,95   5,06       0,02
# 219                NaN           2.085.105,85  10,11   8,07       0,00
# 115                NaN          10.731.003,96  -7,26   6,39       0,00
# 116                NaN           3.735.113,93  -7,26   6,39       0,00
# 237                NaN           4.989.503,93  18,98   4,83      -0,17
# 238                NaN         177.642.337,41  18,98   4,83      -0,16
# 34               57,26           2.818.981,67  19,69  15,40       0,08
# 35               57,26          82.344.398,33  19,69  15,40       0,08
#
#       VALOR DE MERCADO
# 85      288.350.184,96
# 103  11.855.826.027,92
# 104  11.855.826.027,92
# 219     801.383.336,25
# 115     331.617.808,88
# 116     331.617.808,88
# 237  10.030.369.407,12
# 238  10.030.369.407,12
# 34    9.622.065.329,86
# 35    9.622.065.329,86

# %%
data["point"] = 1
data["pointEV/EBIT"] = data['point'].cumsum()

# %%
data = data.sort_values(by=["ROIC"], ascending=False)
data["pointROIC"] = data['point'].cumsum()

# %%
data["pointFinal"] = data["pointEV/EBIT"] + data["pointROIC"]

# %%
data = data.sort_values(by=["pointFinal"])

# %%
data.head(30)
# Out:
#     TICKER  PRECO      DY        P/L  P/VP P/ATIVOS MARGEM BRUTA MARGEM EBIT  \
# 34   BRAP3  23,32   29,75       1,51  1,18     1,17          NaN         NaN
# 35   BRAP4  25,01   30,34       1,63  1,28     1,27          NaN         NaN
# 227  TIMS3  12,28    5,06      11,04  1,17     0,55        52,43       20,24
# 68   CYRE3  19,19    2,96       9,95  1,18     0,52        32,67       17,69
# 3    AERI3   2,04    1,01  31.567,99  1,63     0,47        11,54        8,64
# 12   AMBP3  29,02    1,04      27,23  3,17     0,52        20,78       16,33
# 78   ELET6  48,17    3,35      19,67  1,41     0,59        68,27       32,11
# 77   ELET3  45,92    1,69      18,73  1,34     0,56        68,27       32,11
# 70   DESK3  11,25    0,13      29,91  1,09     0,41        56,48       24,01
# 244  VIVT3  40,21    8,46      12,32  0,99     0,56        43,12       14,59
# 182  PORT3  10,16    4,40      19,76  1,98     0,81        42,98       23,91
# 168  ONCO3   6,99     NaN      33,23  1,93     0,54        34,14       13,25
# 206  SBSP3  58,13    1,62      16,33  1,53     0,73        34,47       20,35
# 230  TRIS3   5,22    4,18      12,17  0,80     0,43        33,54       16,50
# 63   CSMG3  15,59    2,48      13,77  0,84     0,47        33,75       12,42
# 219  SYNE3   5,24  166,28       0,65  0,52     0,18        69,87       68,45
# 240  VAMO3  14,90    1,32      30,96  5,30     1,21        39,40       29,73
# 232  TTEN3  13,31    0,12      14,91  2,73     1,20        13,36        6,33
# 41   BRML3   9,89    0,54      17,36  0,75     0,45        89,71       65,57
# 160  MULT3  25,17    3,64      23,01  2,33     1,40        80,14       54,31
# 87   ESPA3   1,99     NaN      28,79  0,69     0,22        27,62       16,15
# 83   ENEV3  13,57     NaN      18,13  1,58     0,81        38,42       33,00
# 104  GOAU4  11,20   20,54       2,21  0,75     0,16        26,33       26,28
# 145  MATD3   9,43    0,95      28,05  2,15     0,78        36,63       19,70
# 103  GOAU3  10,32   22,29       2,04  0,69     0,14        26,33       26,28
# 205  SBFG3  20,07    0,59       8,74  2,15     0,65        46,34        8,55
# 247  VVEO3  18,63    2,18      18,67  2,39     0,75        16,45        5,34
# 111  IGTA3  33,00     NaN     -60,01  1,75     0,86        59,42       48,46
# 105  GRND3   7,51    5,73      10,77  1,65     1,51        41,66       13,61
# 207  SEER3   7,70    1,61     -16,25  0,70     0,30        52,28        6,66
#
#     MARG. LIQUIDA P/EBIT EV/EBIT DIVIDA LIQUIDA / EBIT DIV. LIQ. / PATRI.  \
# 34            NaN   1,54    1,56                 -0,05              -0,04
# 35            NaN   1,66    1,56                 -0,05              -0,04
# 227         13,88   7,57   11,25                  3,68               0,57
# 68          15,09   8,48   10,31                  1,83               0,25
# 3            0,00   7,59   11,42                  3,83               0,82
# 12           4,13   6,88   12,13                  5,25               2,41
# 78          14,26   8,74   10,25                  1,88               0,30
# 77          14,26   8,32   10,25                  1,88               0,30
# 70           6,00   7,47   11,11                  3,63               0,53
# 244         11,97  10,11   12,10                  1,99               0,19
# 182         10,33   8,54   13,31                  4,77               1,10
# 168          3,32   8,33   11,68                  3,35               0,78
# 206         11,96   9,60   13,03                  3,43               0,55
# 230         10,95   8,08   10,55                  2,48               0,24
# 63           7,10   7,88   11,79                  3,91               0,42
# 219         52,92   0,50    0,88                  0,37               0,38
# 240         13,05  13,59   17,54                  3,95               1,54
# 232          7,22  17,00   18,20                  1,30               0,21
# 41          36,02   9,54   12,16                  2,63               0,21
# 160         41,07  17,40   19,74                  2,34               0,31
# 87           2,37   4,23   11,08                  6,85               1,12
# 83          22,27  12,23   15,16                  2,93               0,38
# 104          6,39   0,54    0,70                  0,18               0,25
# 145          9,84  14,02   16,22                  2,20               0,34
# 103          6,39   0,50    0,70                  0,18               0,25
# 205          9,35   9,56   13,68                  4,12               0,93
# 247          4,10  14,35   17,66                  3,32               0,55
# 111         -9,61  11,91   15,50                  3,60               0,53
# 105         25,23  19,96   16,82                 -3,15              -0,26
# 207         -3,89   9,50   13,60                  4,10               0,30
#
#       PSR P/CAP. GIRO P. AT CIR. LIQ. LIQ. CORRENTE    ROE    ROA   ROIC  \
# 34    NaN       35,37           -1,22          6,01  78,20  77,67  76,80
# 35    NaN       38,15           -1,32          6,01  78,20  77,67  76,80
# 227  1,53      -32,03           -0,65          0,90  10,63   4,96   8,96
# 68   1,50        1,44           -1,15          2,90  11,84   5,21   7,14
# 3    0,66        1,20           -1,38          2,49   0,01   0,00   7,87
# 12   1,12        2,81           -0,87          1,87  11,62   1,92   8,21
# 78   2,81        6,43           -0,75          1,71   7,15   2,98   6,39
# 77   2,67        6,12           -0,71          1,71   7,15   2,98   6,39
# 70   1,79      -16,24           -0,52          0,90   3,63   1,36   6,80
# 244  1,47       -8,66           -0,66          0,70   8,04   4,56   7,24
# 182  2,04   16.741,88           -0,93          1,00  10,00   4,10   8,12
# 168  1,10        2,98           -0,86          2,00   5,82   1,63   6,54
# 206  1,95       22,27           -0,84          1,34   9,39   4,50   7,44
# 230  1,33        0,81           -1,55          3,72   6,54   3,51   5,38
# 63   0,98       15,58           -0,57          1,21   6,10   3,43   6,30
# 219  0,34        1,09           -0,23          4,43  79,85  27,77  38,27
# 240  4,04        6,73           -1,86          2,05  17,13   3,90   9,05
# 232  1,08        3,71           -4,97          1,74  18,30   8,02   9,22
# 41   6,25        8,77           -0,49          2,26   4,30   2,57   5,72
# 160  9,45      165,08           -1,65          1,06  10,14   6,09   9,06
# 87   0,68        7,85           -0,35          1,09   2,41   0,78   4,81
# 83   4,04        6,35           -1,12          1,85   8,69   4,46   6,47
# 104  0,14        0,58           -0,30          2,26  33,85   7,03  29,17
# 145  2,76        4,46           -1,06          3,00   7,67   2,78   6,73
# 103  0,13        0,54           -0,27          2,26  33,85   7,03  29,17
# 205  0,82        2,92           -1,28          1,85  24,60   7,49   5,88
# 247  0,77        2,89           -1,78          1,82  12,79   4,03   6,80
# 111  5,77        7,17           -1,15          1,86  -2,92  -1,42   6,15
# 105  2,72        2,85           -3,77          8,67  15,28  14,03   6,48
# 207  0,63        7,75           -0,37          1,26  -4,33  -1,84   5,19
#
#     PATRIMONIO / ATIVOS PASSIVOS / ATIVOS GIRO ATIVOS CAGR RECEITAS 5 ANOS  \
# 34                 0,99              0,01        0,00                  NaN
# 35                 0,99              0,01        0,00                  NaN
# 227                0,47              0,53        0,36                 2,95
# 68                 0,44              0,52        0,35                 8,44
# 3                  0,29              0,71        0,72                  NaN
# 12                 0,16              0,81        0,46                  NaN
# 78                 0,42              0,58        0,21                -9,01
# 77                 0,42              0,58        0,21                -9,01
# 70                 0,37              0,62        0,23                  NaN
# 244                0,57              0,43        0,38                 0,71
# 182                0,41              0,59        0,40                 6,17
# 168                0,28              0,64        0,49                  NaN
# 206                0,48              0,52        0,38                 6,69
# 230                0,54              0,44        0,32                20,68
# 63                 0,56              0,44        0,48                 7,89
# 219                0,35              0,40        0,52                40,50
# 240                0,23              0,77        0,30               571,04
# 232                0,44              0,56        1,11                  NaN
# 41                 0,60              0,40        0,07                -2,54
# 160                0,60              0,40        0,15                 3,03
# 87                 0,32              0,68        0,33                  NaN
# 83                 0,51              0,49        0,20                18,85
# 104                0,21              0,38        1,10                15,78
# 145                0,36              0,63        0,28                  NaN
# 103                0,21              0,38        1,10                15,78
# 205                0,30              0,70        0,80                22,57
# 247                0,32              0,68        0,98                  NaN
# 111                0,49              0,51        0,15                 5,10
# 105                0,92              0,08        0,56                 2,75
# 207                0,43              0,57        0,47                 4,57
#
#     CAGR LUCROS 5 ANOS  LIQUIDEZ MEDIA DIARIA    VPA    LPA  PEG Ratio  \
# 34               57,26           2.818.981,67  19,69  15,40       0,08
# 35               57,26          82.344.398,33  19,69  15,40       0,08
# 227              29,12         133.690.085,15  10,46   1,11       0,81
# 68               38,37         199.412.685,93  16,22   1,92      -0,16
# 3                  NaN           9.038.776,04   1,26   0,00    -315,82
# 12                 NaN          23.837.252,70   9,17   1,07       1,04
# 78               10,45         137.375.466,96  34,25   2,45      22,90
# 77               10,45         450.569.659,48  34,25   2,45      21,81
# 70                 NaN           2.928.266,59  10,29   0,37       0,66
# 244               6,02         122.250.951,22  40,57   3,26       0,87
# 182              -5,01           7.246.487,81   5,14   0,51      -1,48
# 168                NaN           7.935.469,81   3,62   0,21      -0,25
# 206              -3,75         334.241.245,00  37,90   3,56      -4,63
# 230              98,79           5.154.162,52   6,60   0,43      -0,23
# 63               -0,26          32.261.142,52  18,46   1,13      -0,25
# 219                NaN           2.085.105,85  10,11   8,07       0,00
# 240             549,36          47.455.705,48   2,81   0,48       0,40
# 232                NaN          27.784.707,00   4,88   0,89       0,80
# 41               22,47         131.295.774,89  13,25   0,57       0,08
# 160              16,07         106.438.776,19  10,78   1,09      -0,99
# 87                 NaN          12.520.050,00   2,87   0,07      -0,31
# 83                 NaN         182.082.816,30   8,60   0,75       1,60
# 104                NaN         103.462.068,93  14,95   5,06       0,02
# 145                NaN           4.982.398,07   4,38   0,34       1,06
# 103                NaN             984.303,07  14,95   5,06       0,02
# 205                NaN          31.194.720,15   9,34   2,30       0,00
# 247                NaN           4.141.470,70   7,80   1,00      -1,23
# 111                NaN          70.275.318,31  18,84  -0,55       0,50
# 105              -0,15           9.921.430,56   4,57   0,70       1,32
# 207                NaN           6.452.225,00  10,90  -0,47       0,12
#
#        VALOR DE MERCADO  point  pointEV/EBIT  pointROIC  pointFinal
# 34     9.622.065.329,86      1             9         21          30
# 35     9.622.065.329,86      1            10         20          30
# 227   29.727.478.007,44      1            31         12          43
# 68     7.635.087.460,90      1            18         26          44
# 3      1.578.399.719,36      1            32         22          54
# 12     3.277.390.763,76      1            38         18          56
# 78   106.152.695.860,36      1            17         42          59
# 77   106.152.695.860,36      1            16         43          59
# 70       974.671.427,34      1            30         31          61
# 244   67.429.687.876,91      1            37         25          62
# 182    4.470.080.976,00      1            48         19          67
# 168    3.482.315.365,83      1            33         36          69
# 206   39.752.933.981,04      1            45         24          69
# 230      979.742.074,50      1            22         56          78
# 63     5.901.527.630,88      1            34         45          79
# 219      801.383.336,25      1             4         77          81
# 240   15.278.429.753,00      1            74         11          85
# 232    6.564.959.469,81      1            77          9          86
# 41     8.191.628.712,76      1            39         52          91
# 160   15.121.151.223,75      1            82         10          92
# 87       486.028.776,34      1            29         65          94
# 83    21.469.246.335,20      1            57         38          95
# 104   11.855.826.027,92      1             3         95          98
# 145    3.605.370.212,03      1            65         33          98
# 103   11.855.826.027,92      1             2         96          98
# 205    4.888.974.489,66      1            51         51         102
# 247    5.330.478.196,80      1            76         30         106
# 111    5.758.073.079,00      1            60         47         107
# 105    6.784.243.200,00      1            70         37         107
# 207      986.007.149,60      1            50         58         108

# %%
data.head(30).to_csv('11-10-2022')
